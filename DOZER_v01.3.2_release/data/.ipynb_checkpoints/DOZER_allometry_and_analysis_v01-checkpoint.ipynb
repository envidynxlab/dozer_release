# %%
# Import libraries
import os
import glob
import re

import pandas as pd
import numpy as np
import math
from scipy.stats import mode

from skimage.measure import label, regionprops, perimeter

# # Import curve-fitting package from scipy
# from scipy import signal
# from scipy.optimize import curve_fit
# from scipy import stats
# # from scipy.signal import savgol_filter

import matplotlib as mpl
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# import os
# import glob
# import re

# # Define a function to process files
# def process_files(file_type):
#     # Arrays to store results
#     time = []
#     wash_A = []
#     wash_P = []
#     wash_V = []

#     # set min threshold for sand binary
#     n = 0.01 

#     # Search for files matching the file_type (dozer or no_dozer)
#     pattern = f"*_{file_type}.csv"
#     files = glob.glob(pattern)

#     for file in files:
#         try:
#             # Extract the H/M/S part of the timestamp from the filename
#             filename = os.path.basename(file)
#             timestamp = filename.split('_')[0].split('-')[1]  # Extract H/M/S part

#             # Extract the full datetime stamp
#             datetime_stamp = filename.split('_')[0]  # Option 1: Split method
#             # Or using regex (if you want to validate format):
#             # datetime_match = re.match(r'(\d{8}-\d{6})', filename)
#             # if datetime_match:
#             #     datetime_stamp = datetime_match.group(1)

#             # Save the datetime stamp in an array
#             time.append(datetime_stamp)

#             # Extract the trial number
#             trial_number = re.search(r'trial(\d+)', filename)
#             if trial_number:
#                 trial_number = trial_number.group(1)  # Get the number part
#                 print(f"Trial number: {trial_number}")  # Optional debug print

# %%
# # Define a function to process files
# def process_files(file_type1, file_type2):
#     # Arrays to store results
#     datetime_stamp = []
#     trial_id = []
#     time = []
#     wash_A = []
#     wash_P = []
#     wash_V = []
#     wash_id = []

#     # set min threshold for sand binary
#     n = 0.01

#     # Try to identify/label individual washover units from "final" NODOZ condition (how many would we expect?) – for following...
#     # Search for files matching the file_type (dozer or no_dozer)

#     # Search for files matching the file_type (dozer or no_dozer)
#     pattern1 = f"*_{file_type1}.csv"
#     files1 = glob.glob(pattern1)

#     pattern2 = f"*_{file_type2}.csv"
#     files2 = glob.glob(pattern2)


#     for file in files1:
#         try:
#             # Extract the H/M/S part of the timestamp from the filename
#             filename = os.path.basename(file)

#             # Extract the full datetime stamp
#             dt_stamp = filename.split('_')[0] # extract datetime stamp part of file name
            
#             # Extract just the time stamp
#             timestamp = filename.split('_')[0].split('-')[1]  # Extract H/M/S part

#             # Extract the trial number
#             trial_number = re.search(r'trial(\d+)', filename)
#             if trial_number:
#                 trial_number1 = trial_number.group(1)  # Get the number part
#                 # print(f"Trial number: {trial_number}")  # Optional debug print
                

#             # Load CSV into a numpy array
#             data = np.genfromtxt(file, delimiter=',')

#             # Create binary mask of sand or empty
#             mask_full = (data > n).astype(int)
#             mask = mask_full[3:]

#             # Label connected components in the binary mask
#             labeled_mask_base = label(mask)

#             # Check what the label map looks like
#             # plt.imshow(labeled_mask_base) # binary of washover patterns
#             # plt.colorbar()
#             # plt.show()
            

#             for file in files2:
#                 try:
#                     # Extract the H/M/S part of the timestamp from the filename
#                     filename = os.path.basename(file)
                    
#                     # Extract the full datetime stamp
#                     dt_stamp = filename.split('_')[0] # extract datetime stamp part of file name
                    
#                     # Extract just the time stamp
#                     timestamp = filename.split('_')[0].split('-')[1]  # Extract H/M/S part
        
#                     # Extract the trial number
#                     trial_number = re.search(r'trial(\d+)', filename)
#                     if trial_number:
#                         trial_number2 = trial_number.group(1)  # Get the number part

#                         if trial_number2 == trial_number1:
#                             print(f"Trial number: {trial_number}")  # Optional debug print
                        
        
                
#                             # Load CSV into a numpy array
#                             data = np.genfromtxt(file, delimiter=',')
                
#                             # Create binary mask of sand or empty
#                             mask_full = (data > n).astype(int)
#                             mask = mask_full[3:]
                
#                             # Label connected components in the binary mask
#                             labeled_mask = label(mask)
                            
#                             # Get properties of labeled regions
#                             regions = regionprops(labeled_mask)
#                             # Print the number of regions
#                             # print(f"Number of regions detected: {len(regions)}")
                
#                             # Create a new binary array for the connected components
#                             # connected_components = (labeled_mask > 0).astype(int)
#                             # plt.imshow(labeled_mask, cmap = 'gray') # binary of washover patterns
#                             # plt.show()
                            
#                             # Iterate over regions to calculate area and perimeter
#                             for i, region in enumerate(regions):
                                
#                                 A = region.area  # Number of white pixels
#                                 P = perimeter(region.image)  # Perimeter of the region
                
#                                 # Calculate the volume of the corresponding region within data[3:]
#                                 V = np.sum(data[3:][region.coords[:, 0], region.coords[:, 1]])
        
#                                 # Assign label to corresponding "expected" washover deposit
#                                 eye_dee = mode(labeled_mask_base[region.coords[:, 0], region.coords[:, 1]], axis=None)
#                                 # print(f"Lobe ID: {eye_dee}")
                
                
#                                 if A > 0 and P > 30:
#                                     # Append results to lists
#                                     datetime_stamp.append(dt_stamp)
#                                     trial_id.append(trial_number2)
#                                     time.append(timestamp)
#                                     wash_A.append(A)
#                                     wash_P.append(P)
#                                     wash_V.append(V)
#                                     wash_id.append(eye_dee[0])
                
                
#                 except Exception as e:
#                     print(f"Error processing file {file}: {e}")
                
#             return datetime_stamp, trial_id, time, wash_id, wash_A, wash_P, wash_V
            
#         except Exception as e:
#                 print(f"Error processing file {file}: {e}")

# # Example usage:
# # Process "dozer" files
# # time_D, Area_D, Perimeter_D, Volume_D = process_files("temp_sand_dozer")
# # time_D, Area_D, Perimeter_D, Volume_D = process_files("final_sand_dozer")
# datetime_stamp, trial, time_D, wash_ID_D, Area_D, Perimeter_D, Volume_D = process_files("final_sand_no_dozer", "temp_sand_dozer")


# # Process "no_dozer" files
# # time_ND, Area_ND, Perimeter_ND, Volume_ND = process_files("temp_sand_no_dozer")
# datetime_stamp, trial, time_ND, wash_ID_ND, Area_ND, Perimeter_ND, Volume_ND = process_files("final_sand_no_dozer", "temp_sand_no_dozer")



# # Create a DataFrame from the results
# df_DOZER = pd.DataFrame({
#     'time': time_D,
#     'area DOZER': Area_D,
#     'perimeter DOZER': Perimeter_D,
#     'volume DOZER': Volume_D,
#     'deposit_id': wash_ID_D
# })

# df_DOZER["time"] = df_DOZER.time.astype(float)
# df_DOZER.sort_values(by=['time'], inplace=True)



# df_NODOZ = pd.DataFrame({
#     'time': time_ND,
#     'area ND': Area_ND,
#     'perimeter ND': Perimeter_ND,
#     'volume ND': Volume_ND,
#     'deposit_id': wash_ID_ND
# })

# df_NODOZ["time"] = df_NODOZ.time.astype(float)
# df_NODOZ.sort_values(by=['time'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 138
#     132                 print(f"Error processing file {file}: {e}")
#     134 # Example usage:
#     135 # Process "dozer" files
#     136 # time_D, Area_D, Perimeter_D, Volume_D = process_files("temp_sand_dozer")
#     137 # time_D, Area_D, Perimeter_D, Volume_D = process_files("final_sand_dozer")
# --> 138 datetime_stamp, trial, time_D, Area_D, Perimeter_D, Volume_D, wash_ID_D = process_files("final_sand_no_dozer", "temp_sand_dozer")
#     141 # Process "no_dozer" files
#     142 # time_ND, Area_ND, Perimeter_ND, Volume_ND = process_files("temp_sand_no_dozer")
#     143 datetime_stamp, trial, time_ND, Area_ND, Perimeter_ND, Volume_ND, wash_ID_ND = process_files("final_sand_no_dozer", "temp_sand_no_dozer")
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
def process_files(file_type1, file_type2):
    # Arrays to store results
    datetime_stamp = []
    trial_id = []
    time = []
    wash_A = []
    wash_P = []
    wash_V = []
    wash_id = []

    # set min threshold for sand binary
    n = 0.01

    # Search for files matching the file_type
    pattern1 = f"*_{file_type1}.csv"
    files1 = glob.glob(pattern1)

    pattern2 = f"*_{file_type2}.csv"
    files2 = glob.glob(pattern2)

    for file1 in files1:
        try:
            # Extract the H/M/S part of the timestamp from the filename
            filename1 = os.path.basename(file1)

            # Extract the full datetime stamp
            dt_stamp1 = filename1.split('_')[0]  # extract datetime stamp part of file name
            
            # Extract just the time stamp
            timestamp1 = filename1.split('_')[0].split('-')[1]  # Extract H/M/S part

            # Extract the trial number
            trial_number1 = re.search(r'trial(\d+)', filename1)
            if trial_number1:
                trial_number1 = trial_number1.group(1)  # Get the number part

            # Load CSV into a numpy array
            data1 = np.genfromtxt(file1, delimiter=',')

            # Create binary mask of sand or empty
            mask_full1 = (data1 > n).astype(int)
            mask1 = mask_full1[3:]

            # Label connected components in the binary mask
            labeled_mask_base = label(mask1)

            for file2 in files2:
                try:
                    # Extract the H/M/S part of the timestamp from the filename
                    filename2 = os.path.basename(file2)

                    # Extract the full datetime stamp
                    dt_stamp2 = filename2.split('_')[0]  # extract datetime stamp part of file name

                    # Extract just the time stamp
                    timestamp2 = filename2.split('_')[0].split('-')[1]  # Extract H/M/S part

                    # Extract the trial number
                    trial_number2 = re.search(r'trial(\d+)', filename2)
                    if trial_number2:
                        trial_number2 = trial_number2.group(1)

                        if trial_number2 == trial_number1:
                            # Load CSV into a numpy array
                            data2 = np.genfromtxt(file2, delimiter=',')

                            # Create binary mask of sand or empty
                            mask_full2 = (data2 > n).astype(int)
                            mask2 = mask_full2[3:]

                            # Label connected components in the binary mask
                            labeled_mask2 = label(mask2)

                            # Get properties of labeled regions
                            regions = regionprops(labeled_mask2)

                            # Iterate over regions to calculate area and perimeter
                            for region in regions:
                                A = region.area  # Number of white pixels
                                P = perimeter(region.image)  # Perimeter of the region

                                # Calculate the volume of the corresponding region within data2[3:]
                                V = np.sum(data2[3:][region.coords[:, 0], region.coords[:, 1]])

                                # Assign label to corresponding "expected" washover deposit
                                eye_dee = mode(labeled_mask_base[region.coords[:, 0], region.coords[:, 1]], axis=None)

                                if A > 0 and P > 30:
                                    # Append results to lists
                                    datetime_stamp.append(dt_stamp2)
                                    trial_id.append(trial_number2)
                                    time.append(timestamp2)
                                    wash_A.append(A)
                                    wash_P.append(P)
                                    wash_V.append(V)
                                    wash_id.append(eye_dee[0])

                except Exception as e:
                    print(f"Error processing file {file2}: {e}")

        except Exception as e:
            print(f"Error processing file {file1}: {e}")

    return datetime_stamp, trial_id, time, wash_id, wash_A, wash_P, wash_V

datetime_stamp, trial, time_D, wash_ID_D, Area_D, Perimeter_D, Volume_D = process_files("final_sand_no_dozer", "temp_sand_dozer")
datetime_stamp, trial, time_ND, wash_ID_ND, Area_ND, Perimeter_ND, Volume_ND = process_files("final_sand_no_dozer", "temp_sand_no_dozer")

# %%
# Create a DataFrame from the results
df_DOZER = pd.DataFrame({
    'date stamp': datetime_stamp,
    'trial': trial,
    'time': time_D,
    'deposit_id': wash_ID_D
    'perimeter DOZER': Perimeter_D,
    'area DOZER': Area_D,
    'volume DOZER': Volume_D
})

df_DOZER["time"] = df_DOZER.time.astype(float)
df_DOZER.sort_values(by=['time'], inplace=True)

# %%
f, ax = plt.subplots(figsize = (6, 6))

custom = {'font': 'Arial',
               'xtick.direction': 'in',
               'ytick.direction': 'in',
               'xtick.top': 'True',
               'ytick.right': 'True'}

sns.set_style('ticks', rc = custom)

# plt.plot(df_DOZER['area DOZER'], df_DOZER['perimeter DOZER'], 'r', linewidth = 0.25)
# plt.plot(df_NODOZ['area ND'], df_NODOZ['perimeter ND'], 'b', linewidth = 0.25)

# plt.plot(df_DOZER['area DOZER'], df_DOZER['volume DOZER'], 'r', linewidth = 0.25)
# plt.plot(df_NODOZ['area ND'], df_NODOZ['volume ND'], 'b', linewidth = 0.25)

plt.plot(df_DOZER[df_DOZER['deposit_id'] == 1]['area DOZER'], df_DOZER[df_DOZER['deposit_id'] == 1]['volume DOZER'], 'r', linewidth = 0.25, zorder=1)
plt.plot(df_DOZER[df_DOZER['deposit_id'] == 2]['area DOZER'], df_DOZER[df_DOZER['deposit_id'] == 2]['volume DOZER'], 'r', linewidth = 0.25, zorder=1)

plt.plot(df_NODOZ[df_NODOZ['deposit_id'] == 1]['area ND'], df_NODOZ[df_NODOZ['deposit_id'] == 1]['volume ND'], 'b', linewidth = 0.25, zorder=1)
plt.plot(df_NODOZ[df_NODOZ['deposit_id'] == 2]['area ND'], df_NODOZ[df_NODOZ['deposit_id'] == 2]['volume ND'], 'b', linewidth = 0.25, zorder=1)

sns.scatterplot(data = df_DOZER,
            x = 'area DOZER', y = 'volume DOZER',
            hue = 'time',
            palette = 'Reds',
            style = 'deposit_id',
            legend = False,
            color = 'red',
            edgecolor = 'black',
            linewidth = 0.5)

sns.scatterplot(data = df_NODOZ,
            x = 'area ND', y = 'volume ND',
            hue = 'time',
            palette = 'Blues',
            style = 'deposit_id',
            legend = False,
            # color = 'blue',
            edgecolor = 'black',
            linewidth = 0.5)

sns.despine(right=False, top=False)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_box_aspect(1)

ax.set_xlabel('area ($\mathregular{m^2}$)')
ax.set_ylabel('perimeter (m)')
# ax.legend(loc = 'lower right')

# %%
# # Define a function to process files
# def process_files(file_type):
#     # Arrays to store results
#     datetime_stamp = []
#     time = []
#     wash_A = []
#     wash_P = []
#     wash_V = []

#     # set min threshold for sand binary
#     n = 0.01 

#     # Search for files matching the file_type (dozer or no_dozer)
#     pattern = f"*_{file_type}.csv"
#     files = glob.glob(pattern)

#     for file in files:
#         try:
#             # Extract the H/M/S part of the timestamp from the filename
#             filename = os.path.basename(file)

#             # Extract the full datetime stamp
#             dt_stamp = filename.split('_')[0]
            
#             timestamp = filename.split('_')[0].split('-')[1]  # Extract H/M/S part

#             # Load CSV into a numpy array
#             data = np.genfromtxt(file, delimiter=',')

#             # Create binary mask of sand or empty
#             mask_full = (data > n).astype(int)
#             mask = mask_full[3:]

#             # Label connected components in the binary mask
#             labeled_mask = label(mask)
            
#             # Get properties of labeled regions
#             regions = regionprops(labeled_mask)
#             # Print the number of regions
#             print(f"Number of regions detected: {len(regions)}")

#             # Create a new binary array for the connected components
#             # connected_components = (labeled_mask > 0).astype(int)
#             plt.imshow(labeled_mask, cmap = 'gray') # binary of washover patterns
#             plt.colorbar()
#             plt.show()
            
#             # Iterate over regions to calculate area and perimeter
#             for i, region in enumerate(regions):
                
#                 A = region.area  # Number of white pixels
#                 P = perimeter(region.image)  # Perimeter of the region

#                 # Calculate the volume of the corresponding region within data[3:]
#                 V = np.sum(data[3:][region.coords[:, 0], region.coords[:, 1]])


#                 if A > 0 and P > 30:
#                     # Append results to lists
#                     datetime_stamp.append(dt_stamp)
#                     time.append(timestamp)
#                     wash_A.append(A)
#                     wash_P.append(P)
#                     wash_V.append(V)


#         except Exception as e:
#             print(f"Error processing file {file}: {e}")

#     return time, wash_A, wash_P, wash_V, labeled_mask

# # Example usage:
# # Process "dozer" files
# # time_D, Area_D, Perimeter_D, Volume_D = process_files("temp_sand_dozer")
# # time_D, Area_D, Perimeter_D, Volume_D = process_files("final_sand_dozer")


# # Process "no_dozer" files
# # time_ND, Area_ND, Perimeter_ND, Volume_ND = process_files("temp_sand_no_dozer")
# time_ND, Area_ND, Perimeter_ND, Volume_ND, labeled_mask = process_files("final_sand_no_dozer")



# # Create a DataFrame from the results
# df_DOZER = pd.DataFrame({
#     'time': time_D,
#     'area DOZER': Area_D,
#     'perimeter DOZER': Perimeter_D,
#     'volume DOZER': Volume_D
# })

# df_DOZER["time"] = df_DOZER.time.astype(float)
# df_DOZER.sort_values(by=['time'], inplace=True)



# df_NODOZ = pd.DataFrame({
#     'time': time_ND,
#     'area ND': Area_ND,
#     'perimeter ND': Perimeter_ND,
#     'volume ND': Volume_ND
# })

# df_NODOZ["time"] = df_NODOZ.time.astype(float)
# df_NODOZ.sort_values(by=['time'], inplace=True)

# # df_DOZER

# %%
df_DOZER.info()

# %%
df_NODOZ.info()

# %%
# Merge the two dataframes on 'time' and 'id'
merged_df = pd.merge(df_DOZER, df_NODOZ, on=['time', 'deposit_id'])

merged_df

# %%
merged_df.info()

# %%
fig, ax = plt.subplots(figsize = (6, 6))

plt.plot(merged_df['area ND'], merged_df['area DOZER'], 'ok') # washover volume with DOZER

# Add the 1:1 reference line
plt.plot([0, max(merged_df['area ND'])], [0, max(merged_df['area ND'])], color='k', linestyle='--', linewidth = 0.75)

plt.xlabel('without DOZER')
plt.ylabel('with DOZER')

# %%
f, ax = plt.subplots(figsize = (6, 6))

custom = {'font': 'Arial',
               'xtick.direction': 'in',
               'ytick.direction': 'in',
               'xtick.top': 'True',
               'ytick.right': 'True'}

sns.set_style('ticks', rc = custom)

plt.plot([0, max(merged_df['area ND'])], [0, max(merged_df['area ND'])], color='k', linestyle='--', linewidth = 0.75, zorder = 1)

sns.scatterplot(data = merged_df,
            x = 'area ND', y = 'area DOZER',
            hue = 'time',
            palette = 'gray_r',
            style = 'deposit_id',
            legend = False,
            # color = 'red',
            edgecolor = 'black',
            linewidth = 0.5)

sns.despine(right=False, top=False)
ax.set_box_aspect(1)
plt.axis("tight")


ax.set_xlabel('without DOZER')
ax.set_ylabel('with DOZER')

# ax.set_xlabel('area ($\mathregular{m^2}$)')
# ax.set_ylabel('perimeter (m)')
# ax.legend(loc = 'lower right')

# %%
f, ax = plt.subplots(figsize = (6, 6))

custom = {'font': 'Arial',
               'xtick.direction': 'in',
               'ytick.direction': 'in',
               'xtick.top': 'True',
               'ytick.right': 'True'}

sns.set_style('ticks', rc = custom)

plt.plot([0, max(merged_df['perimeter ND'])], [0, max(merged_df['perimeter ND'])], color='k', linestyle='--', linewidth = 0.75, zorder = 1)

sns.scatterplot(data = merged_df,
            x = 'perimeter ND', y = 'perimeter DOZER',
            hue = 'time',
            palette = 'gray_r',
            style = 'deposit_id',
            legend = False,
            # color = 'red',
            edgecolor = 'black',
            linewidth = 0.5)

sns.despine(right=False, top=False)
ax.set_box_aspect(1)
plt.axis("tight")


ax.set_xlabel('without DOZER')
ax.set_ylabel('with DOZER')

# %%
f, ax = plt.subplots(figsize = (6, 6))

custom = {'font': 'Arial',
               'xtick.direction': 'in',
               'ytick.direction': 'in',
               'xtick.top': 'True',
               'ytick.right': 'True'}

sns.set_style('ticks', rc = custom)

plt.plot([0, max(merged_df['volume ND'])], [0, max(merged_df['volume ND'])], color='k', linestyle='--', linewidth = 0.75, zorder = 1)

sns.scatterplot(data = merged_df,
            x = 'volume ND', y = 'volume DOZER',
            hue = 'time',
            palette = 'gray_r',
            style = 'deposit_id',
            legend = False,
            # color = 'red',
            edgecolor = 'black',
            linewidth = 0.5)

sns.despine(right=False, top=False)
ax.set_box_aspect(1)
plt.axis("tight")


ax.set_xlabel('without DOZER')
ax.set_ylabel('with DOZER')

# %%
# # Create a DataFrame from the results
# df_DOZER = pd.DataFrame({
#     'time': time_D,
#     'area DOZER': Area_D,
#     'perimeter DOZER': Perimeter_D
#     # 'perimeter NODOZ': Perimeter_ND
# })

# df_DOZER["time"] = df_DOZER.time.astype(float)

# # df_DOZER

# %%
# # Create a DataFrame from the results
# df_NODOZ = pd.DataFrame({
#     'time': time_ND,
#     'area ND': Area_ND,
#     'perimeter ND': Perimeter_ND
#     # 'perimeter NODOZ': Perimeter_ND
# })

# df_NODOZ["time"] = df_NODOZ.time.astype(float)

# # df_NODOZ.sort_values(by=['time'], inplace=True)

# # df_NODOZ

# %%
df_DOZER

# %%
df_NODOZ

# %%
df = pd.read_csv("20250123-072503_Qmove_series.csv")
df

# %%
fig, ax = plt.subplots(figsize = (18, 6))
plt.plot(df['pulse_time'], df['Qm_D'], 'r') # washover volume with DOZER
plt.plot(df['pulse_time'], df['Qm_ND'], 'k') # washover volume without DOZER

# %%
fig, ax = plt.subplots(figsize = (6, 6))
plt.plot(df['Qm_ND'], df['Qm_D'], 'ok') # washover volume with DOZER
# Add the 1:1 reference line
plt.plot([0, max(df['Qm_ND'])], [0, max(df['Qm_ND'])], color='k', linestyle='--', linewidth = 0.75)
plt.xlabel('Qm without DOZER')
plt.ylabel('Qm with DOZER')

# %%
# Import the saved data:
dozer_data = pd.read_csv("20250110-114341.csv")
sand_dozer = pd.read_csv("20250110-114341_sand_dozer.csv")
sand_no_dozer = pd.read_csv("20250110-114341_sand_no_dozer.csv")

# %%
dozer_data.head(3) # check to confirm

# %%
dozer_data.tail(3) # check to confirm

# %%
# See the tracks and start/finish points...
fig, ax = plt.subplots(figsize = (6, 6))
plt.plot(dozer_data['dozer_x'], 720 - dozer_data['dozer_y'], 'k')

# plt.plot(dozer_data['dozer_x'].iloc[-1], 720 - dozer_data['dozer_y'].iloc[-1], 'ro')
# plt.plot(dozer_data['dozer_x'].iloc[0], 720 - dozer_data['dozer_y'].iloc[0], 'go')

plt.plot(dozer_data['dozer_x'].iloc[0], 720 - dozer_data['dozer_y'].iloc[0],
         marker='o', markerfacecolor='white', markeredgecolor='black', markeredgewidth=1.5, markersize=8)
plt.plot(dozer_data['dozer_x'].iloc[-1], 720 - dozer_data['dozer_y'].iloc[-1],
         marker='o', markerfacecolor='black', markeredgecolor='black', markeredgewidth=1.5, markersize=8)

# Set x and y axis limits to match game screen size:
ax.set_xlim(0, 960)
ax.set_ylim(0, 720)

# %%
# Timeseries...
fig, ax = plt.subplots(figsize = (18, 6))
plt.plot(dozer_data['run_time'], dozer_data['washover_vol_doz'], 'k') # washover volume with DOZER
plt.plot(dozer_data['run_time'], dozer_data['washover_vol_wo_doz'], '--b') # washover volume without DOZER
plt.plot(dozer_data['run_time'], dozer_data['dozer_Qs_tot'], 'r') # amount of sand DOZER moved (cumulative)

# %%
# More timeseries...
fig, ax = plt.subplots(figsize = (18, 6))
plt.plot(dozer_data['run_time'], dozer_data['dozer_Qs'], 'k')

# %%
# More timeseries...
fig, ax = plt.subplots(figsize = (18, 6))
plt.plot(dozer_data['run_time'], dozer_data['danger_score'], 'm')

# %%
# More timeseries...
fig, ax = plt.subplots(figsize = (18, 6))
plt.plot(dozer_data['run_time'], dozer_data['sand_diff_pos'], 'b') # POSITIVE change because of DOZER actions (direct and indirect)
plt.plot(dozer_data['run_time'], dozer_data['sand_diff_neg'].abs(), 'r') # NEGATIVE change (absolute val) because of DOZER actions

# %%
# More timeseries...
fig, ax = plt.subplots(figsize = (18, 6))
plt.plot(dozer_data['run_time'], dozer_data['lateral_disp'], 'k')

# %%
plt.imshow(sand_dozer[3:], cmap = 'Reds')
plt.colorbar()

plt.show()

# %%
plt.imshow(sand_no_dozer[3:], cmap = 'Blues')
plt.colorbar()

plt.show()

# %%
plt.imshow(sand_dozer[3:] - sand_no_dozer[3:], cmap = 'PiYG') # difference map of final sand patterns
plt.colorbar()

plt.show()
